# %% [markdown]
# # ADAPT Hand stiffness control — compliance matching demo
#
# End-to-end demonstration of closed-loop stiffness regulation: the hand grasps objects
# of different compliance (rigid, medium, soft) and adapts its virtual stiffness $K_d$
# online to match each object. Shows stiffening on contact and softening on crumpling.
